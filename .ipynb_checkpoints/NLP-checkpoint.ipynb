# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)
from razdel import tokenize
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
import matplotlib.pyplot as plt

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

# %%
def create_dataframe(matrix, tokens):

    doc_names = [f'doc_{i}' for i, _ in enumerate(matrix)]
    df = pd.DataFrame(data=matrix, index=doc_names, columns=tokens)
    return(df)

# %%
def Doc_func(text, segmenter=segmenter, morph_tagger=morph_tagger):
    try:
        doc_temp = Doc(text)
        doc_temp.segment(segmenter)
        doc_temp.tag_morph(morph_tagger)
        for token in doc_temp.tokens:
            token.lemmatize(morph_vocab)
        return ' '.join([
        #_.pos + "," +
        #_.text:
        _.lemma for _ in doc_temp.tokens if _.pos not in  ['PUNCT', 'ADP', 'CCONJ', 'PRON', 'SYM', 'SCONJ', 'DET', 'NUM']])
    except:
        pass

# %%
df = pd.read_excel("RPD_output/dataset.xlsx")

# %%
df['Doc'] = df['content'].apply(Doc_func)

# %%
df = df[['title', 'Doc']]

# %%
df
# Out:
#                                                 title  \
# 0                  Тестирование информационных систем
# 1          Информационные технологии в цифровой среде
# 2     Инструментальные средства информационных систем
# 3   Корпоративные информационные системы и разрабо...
# 4   Методы и средства разработки информационных си...
# 5             Анализ данных в управлении предприятием
# 6   Проектирование и разработка информационных систем
# 7                           Разработка Web-приложений
# 8                                   Машинное обучение
# 9               Интеллектуальные системы и технологии
# 10                                          Философия
# 11                                   Программирование
# 12                               Операционные системы
# 13                  Архитектура информационных систем
# 14               Введение в информационные технологии
# 15                              Дискретная математика
# 16                Инфокоммуникационные системы и сети
# 17                                     История России
# 18                                     МАТЕМАТИКА 3.3
# 19                                       Основы права
# 20                Основы российской государственности
# 21  Английский язык в сфере информационных технологий
# 22          Учебно-исследовательская работа студентов
# 23                                 Электротехника 1.3
# 24                                 Управление данными
# 25                          Эргономика цифровой среды
# 26                  Основы программирования Ha Python
# 27                        Бизнес-анализ в IT-проектах
# 28                     Безопасность жизнедеятельности
# 29                  Введение в проектную деятельность
# 30                                    Информатика 1.2
# 31                      Иностранный язык (английский)
# 32                                     МАТЕМАТИКА 1.3
# 33                                     МАТЕМАТИКА 2.3
# 34                                     МАТЕМАТИКА 4.1
# 35                                 Методы оптимизации
# 36     Методы и средства управления бизнес-процессами
# 37  Начертательная геометрия и инженерная графика 1.4
# 38                                         Физика 1.2
# 39                                         Физика 2.2
# 40                                         Физика 3.2
# 41                        Физическая культура и спорт
# 42               Экономика и организация производства
# 43  Технология командной разработки программного о...
# 44           Теория информационных процессов и систем
# 45                                     Учебный проект
# 46                 Численное решение инженерных задач
#
#                                                   Doc
# 0   основной вид учебный деятельность раздел дисци...
# 1   основной вид учебный деятельность формировать ...
# 2   основной вид учебный деятельность формировать ...
# 3   основной вид учебный деятельность формировать ...
# 4   основной вид учебный деятельность формировать ...
# 5   основной вид учебный деятельность формировать ...
# 6   основной вид учебный деятельность формировать ...
# 7   основной вид учебный деятельность формировать ...
# 8   основной вид учебный деятельность формировать ...
# 9   модуль раздел дисциплина формировать вид учебн...
# 10  основной вид учебный деятельность иук у и ук у...
# 11  основной вид учебный деятельность формировать ...
# 12  основной вид учебный деятельность формировать ...
# 13  основной вид учебный деятельность формировать ...
# 14  основной вид учебный деятельность формировать ...
# 15  основной вид учебный деятельность формировать ...
# 16  основной вид учебный деятельность формировать ...
# 17  основной вид учебный деятельность раздел дисци...
# 18  основной вид учебный деятельность раздел дисци...
# 19  основной вид учебный деятельность раздел дисци...
# 20  основной вид учебный деятельность раздел дисци...
# 21  6 семестр основной вид учебный деятельность фо...
# 22  содержание этап реализация дисциплина этап реа...
# 23  основной вид учебный деятельность формировать ...
# 24  основной вид учебный деятельность формировать ...
# 25  основной вид учебный деятельность формировать ...
# 26  основной вид учебный деятельность формировать ...
# 27  основной вид учебный деятельность формировать ...
# 28  основной вид учебный деятельность раздел дисци...
# 29  основной вид учебный деятельность формировать ...
# 30  основной вид учебный деятельность раздел дисци...
# 31  основной вид учебный деятельность объем время ...
# 32  основной вид учебный деятельность раздел дисци...
# 33  основной вид учебный деятельность раздел дисци...
# 34  основной вид учебный деятельность раздел дисци...
# 35  основной вид учебный деятельность формировать ...
# 36  основной вид учебный деятельность формировать ...
# 37  основной вид учебный деятельность раздел дисци...
# 38  основной вид учебный деятельность 3 формироват...
# 39  основной вид учебный деятельность 3 формироват...
# 40  основной вид учебный деятельность формировать ...
# 41  учебный деятельность основной вид формировать ...
# 42  основной вид учебный деятельность раздел дисци...
# 43  основной вид учебный деятельность формировать ...
# 44  основной вид учебный деятельность формировать ...
# 45  содержание этап реализация дисциплина этап реа...
# 46  основной вид учебный деятельность формировать ...

# %%
df.to_excel(r'RPD_output/dataset_res.xlsx')
df.to_csv(r'RPD_output/dataset_res.csv', encoding="utf-8-sig")
#ngram_range=(1, 2)

# %%
tfidf_vect = TfidfVectorizer()
tfidf_matrix = tfidf_vect.fit_transform(df['Doc'])
feature_names = tfidf_vect.get_feature_names_out()

list_output1 = []
for i in range(len(tfidf_matrix.toarray())):
    tfidf_scores = tfidf_matrix.toarray()[i]
    sorted_features = [list(filter(lambda c: c[0] > 0.02, sorted(zip(tfidf_scores, feature_names), reverse=True)))]
    list_output1.append(sorted_features)

# %%
df.insert(2, "key_words", list_output1)

# %%
df.to_excel(r'RPD_output/dataset_res2.xlsx')

# %% [markdown]
# # Косинусное расстояние

# %%
tfidf_vect2 = TfidfVectorizer()
tfidf_matrix2 = tfidf_vect2.fit_transform(df['Doc'])
feature_names2 = tfidf_vect2.get_feature_names_out()

list_output2 = []
for i in range(len(tfidf_matrix2.toarray())):
    tfidf_scores2 = tfidf_matrix2.toarray()[i]
    sorted_features2 = [feature for _, feature in list(filter(lambda c: c[0] > 0.1, sorted(zip(tfidf_scores2, feature_names2), reverse=True)))]
    list_output2.append(sorted_features2)

# %%
list_output3 = []
for elem in list_output2:
    list_output3.append(" ".join(elem))

# %%
tfidf_vect3 = TfidfVectorizer()
tfidf_matrix3 = tfidf_vect3.fit_transform(list_output3)
feature_names3 = tfidf_vect3.get_feature_names_out()

# %%
cosine_similarity_matrix  = cosine_similarity(tfidf_matrix3)
create_dataframe(tfidf_matrix3.toarray(), feature_names3)
# Out:
#               20       and  business    career  continuous  directum  \
# doc_0   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_1   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_2   0.000000  0.000000  0.281521  0.000000    0.000000  0.281521
# doc_3   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_4   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_5   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_6   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_7   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_8   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_9   0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_10  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_11  0.268164  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_12  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_13  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_14  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_15  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_16  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_17  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_18  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_19  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_20  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_21  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_22  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_23  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_24  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_25  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_26  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_27  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_28  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_29  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_30  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_31  0.000000  0.208514  0.000000  0.208514    0.208514  0.000000
# doc_32  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_33  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_34  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_35  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_36  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_37  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_38  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_39  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_40  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_41  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_42  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_43  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_44  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_45  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
# doc_46  0.000000  0.000000  0.000000  0.000000    0.000000  0.000000
#
#         educational  engineering  framework      html  ...      эмп  \
# doc_0      0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_1      0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_2      0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_3      0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_4      0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_5      0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_6      0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_7      0.000000     0.000000   0.000000  0.407646  ...  0.00000
# doc_8      0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_9      0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_10     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_11     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_12     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_13     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_14     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_15     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_16     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_17     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_18     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_19     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_20     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_21     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_22     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_23     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_24     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_25     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_26     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_27     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_28     0.000000     0.000000   0.000000  0.000000  ...  0.19105
# doc_29     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_30     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_31     0.208514     0.208514   0.000000  0.000000  ...  0.00000
# doc_32     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_33     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_34     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_35     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_36     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_37     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_38     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_39     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_40     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_41     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_42     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_43     0.000000     0.000000   0.249289  0.000000  ...  0.00000
# doc_44     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_45     0.000000     0.000000   0.000000  0.000000  ...  0.00000
# doc_46     0.000000     0.000000   0.000000  0.000000  ...  0.00000
#
#         эмпирический  эргономика  эргономический      этап     этика  \
# doc_0       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_1       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_2       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_3       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_4       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_5       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_6       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_7       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_8       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_9       0.000000     0.00000         0.00000  0.000000  0.000000
# doc_10      0.000000     0.00000         0.00000  0.000000  0.222364
# doc_11      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_12      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_13      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_14      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_15      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_16      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_17      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_18      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_19      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_20      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_21      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_22      0.000000     0.00000         0.00000  0.212897  0.000000
# doc_23      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_24      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_25      0.000000     0.27253         0.27253  0.000000  0.000000
# doc_26      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_27      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_28      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_29      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_30      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_31      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_32      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_33      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_34      0.251798     0.00000         0.00000  0.000000  0.000000
# doc_35      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_36      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_37      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_38      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_39      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_40      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_41      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_42      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_43      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_44      0.000000     0.00000         0.00000  0.000000  0.000000
# doc_45      0.000000     0.00000         0.00000  0.214910  0.000000
# doc_46      0.000000     0.00000         0.00000  0.000000  0.000000
#
#              это  эффективность   ядерный      язык
# doc_0   0.000000       0.000000  0.000000  0.000000
# doc_1   0.000000       0.000000  0.000000  0.000000
# doc_2   0.000000       0.000000  0.000000  0.000000
# doc_3   0.000000       0.000000  0.000000  0.000000
# doc_4   0.000000       0.000000  0.000000  0.000000
# doc_5   0.000000       0.000000  0.000000  0.000000
# doc_6   0.000000       0.000000  0.000000  0.000000
# doc_7   0.000000       0.000000  0.000000  0.340017
# doc_8   0.000000       0.000000  0.000000  0.000000
# doc_9   0.000000       0.000000  0.000000  0.000000
# doc_10  0.000000       0.000000  0.000000  0.000000
# doc_11  0.000000       0.000000  0.000000  0.000000
# doc_12  0.000000       0.000000  0.000000  0.000000
# doc_13  0.000000       0.000000  0.000000  0.000000
# doc_14  0.000000       0.000000  0.000000  0.000000
# doc_15  0.000000       0.000000  0.000000  0.000000
# doc_16  0.000000       0.000000  0.000000  0.000000
# doc_17  0.000000       0.000000  0.000000  0.000000
# doc_18  0.000000       0.000000  0.000000  0.000000
# doc_19  0.000000       0.000000  0.000000  0.000000
# doc_20  0.000000       0.000000  0.000000  0.000000
# doc_21  0.000000       0.000000  0.000000  0.207718
# doc_22  0.000000       0.000000  0.000000  0.000000
# doc_23  0.000000       0.000000  0.000000  0.000000
# doc_24  0.000000       0.000000  0.000000  0.000000
# doc_25  0.000000       0.000000  0.000000  0.000000
# doc_26  0.000000       0.000000  0.000000  0.221395
# doc_27  0.000000       0.259652  0.000000  0.000000
# doc_28  0.000000       0.000000  0.000000  0.000000
# doc_29  0.256023       0.000000  0.000000  0.000000
# doc_30  0.000000       0.000000  0.000000  0.000000
# doc_31  0.000000       0.000000  0.000000  0.000000
# doc_32  0.000000       0.000000  0.000000  0.000000
# doc_33  0.000000       0.000000  0.000000  0.000000
# doc_34  0.000000       0.000000  0.000000  0.000000
# doc_35  0.000000       0.000000  0.000000  0.000000
# doc_36  0.000000       0.275495  0.000000  0.000000
# doc_37  0.000000       0.000000  0.000000  0.000000
# doc_38  0.000000       0.000000  0.000000  0.000000
# doc_39  0.000000       0.000000  0.000000  0.000000
# doc_40  0.000000       0.000000  0.279341  0.000000
# doc_41  0.000000       0.000000  0.000000  0.000000
# doc_42  0.000000       0.213271  0.000000  0.000000
# doc_43  0.000000       0.000000  0.000000  0.000000
# doc_44  0.000000       0.000000  0.000000  0.000000
# doc_45  0.000000       0.000000  0.000000  0.000000
# doc_46  0.000000       0.000000  0.000000  0.000000
#
# [47 rows x 545 columns]

# %%
doc_names_list = [f'doc_{i}' for i, _ in enumerate(cosine_similarity_matrix)]

# %%
dataframe_hm = create_dataframe(cosine_similarity_matrix, doc_names_list)

# %%
plt.figure(figsize = (24,16))
sns.heatmap(dataframe_hm, cmap="Blues", annot=True, fmt=".1f") 
#, annot= True,fmt=".1f"
# Out:
# <Axes: >

# %% [markdown]
# Датасет из Роснавыка (из столбца "Ключевые навыки")

# %%
df_rn_raw = pd.read_excel("rosnavik/dataset.xlsx")

# %%
df_rn = df_rn_raw[df_rn_raw['Ключевые навыки'].notnull()]
df_rn = df_rn[['Специализация', 'Ключевые навыки']]
df_rn
# Out:
#                   Специализация  \
# 6      Программист, разработчик
# 12     Программист, разработчик
# 14     Программист, разработчик
# 22     Программист, разработчик
# 23     Программист, разработчик
# ...                         ...
# 55743       Финансовый менеджер
# 55746       Финансовый менеджер
# 55749       Финансовый менеджер
# 55750       Финансовый менеджер
# 55751       Финансовый менеджер
#
#                                          Ключевые навыки
# 6      HTML/CSS;HTML/CSS;HTML/CSS;Javascript;Javascri...
# 12                   Знание базовых принципов разработки
# 14     1С: Бухгалтерия;1С: Предприятие;1С: Предприяти...
# 22                                            Javascript
# 23     Знание английского языка;Ответственность и про...
# ...                                                  ...
# 55743  Microsoft Excel;Ведение отчетности;Проведение ...
# 55746  Аналитическое мышление;Бюджетирование;Бюджетир...
# 55749  Работа с поставщиками;Финансовый анализ;Налого...
# 55750  Клиент-Банк;Ведение бухгалтерского учета;Веден...
# 55751  Microsoft PowerPoint;Анализ данных;Анализ фина...
#
# [33181 rows x 2 columns]

# %%
df_rn['Ключевые навыки'].str.replace(';',' ')
# Out:
# 6        HTML/CSS HTML/CSS HTML/CSS Javascript Javascri...
# 12                     Знание базовых принципов разработки
# 14       1С: Бухгалтерия 1С: Предприятие 1С: Предприяти...
# 22                                              Javascript
# 23       Знание английского языка Ответственность и про...
#                                ...
# 55743    Microsoft Excel Ведение отчетности Проведение ...
# 55746    Аналитическое мышление Бюджетирование Бюджетир...
# 55749    Работа с поставщиками Финансовый анализ Налого...
# 55750    Клиент-Банк Ведение бухгалтерского учета Веден...
# 55751    Microsoft PowerPoint Анализ данных Анализ фина...
# Name: Ключевые навыки, Length: 33181, dtype: object

# %%
df_rn['Ключевые навыки+'] = df_rn['Ключевые навыки'].apply(Doc_func)

# %%
df_rn
# Out:
#                   Специализация  \
# 6      Программист, разработчик
# 12     Программист, разработчик
# 14     Программист, разработчик
# 22     Программист, разработчик
# 23     Программист, разработчик
# ...                         ...
# 55743       Финансовый менеджер
# 55746       Финансовый менеджер
# 55749       Финансовый менеджер
# 55750       Финансовый менеджер
# 55751       Финансовый менеджер
#
#                                          Ключевые навыки  \
# 6      HTML/CSS;HTML/CSS;HTML/CSS;Javascript;Javascri...
# 12                   Знание базовых принципов разработки
# 14     1С: Бухгалтерия;1С: Предприятие;1С: Предприяти...
# 22                                            Javascript
# 23     Знание английского языка;Ответственность и про...
# ...                                                  ...
# 55743  Microsoft Excel;Ведение отчетности;Проведение ...
# 55746  Аналитическое мышление;Бюджетирование;Бюджетир...
# 55749  Работа с поставщиками;Финансовый анализ;Налого...
# 55750  Клиент-Банк;Ведение бухгалтерского учета;Веден...
# 55751  Microsoft PowerPoint;Анализ данных;Анализ фина...
#
#                                         Ключевые навыки+
# 6      html css html css html css javascript javascri...
# 12                     знание базовый принцип разработка
# 14     с бухгалтерия с предприятие с предприятие упра...
# 22                                            javascript
# 23     знание английский язык ответственность проакти...
# ...                                                  ...
# 55743  microsoft excel ведение отчетность проведение ...
# 55746  аналитический мышление бюджетирование бюджетир...
# 55749  работа поставщик финансовый анализ налоговый у...
# 55750  клиент-банк ведение бухгалтерский учет ведение...
# 55751  microsoft powerpoint анализ данные анализ фина...
#
# [33181 rows x 3 columns]

# %%
df_rn = df_rn[['Специализация', 'Ключевые навыки+']]

# %%
df_rn = df_rn.groupby('Специализация', as_index = False).agg({'Ключевые навыки+': ','.join})
df_rn
# Out:
#                                        Специализация  \
# 0  BI-аналитик, аналитик данных; Маркетолог-анали...
# 1                                           Аналитик
# 2                                    Бизнес-аналитик
# 3                                      Бизнес-тренер
# 4                                  Менеджер продукта
# 5                  Оператор ПК, оператор базы данных
# 6                           Программист, разработчик
# 7                                 Системный аналитик
# 8                                Финансовый менеджер
#
#                                     Ключевые навыки+
# 0  применение метод itsm microsoft sql server зна...
# 1  microsoft excel python sql sql целеустремленно...
# 2  bpmn работа crm-система directum rx применение...
# 3  обучаемость адаптивность коучинг проведение тр...
# 4  продажа публичный выступление проведение презе...
# 5  ответственность проактивность самоорганизованн...
# 6  html css html css html css javascript javascri...
# 7  bpmn javascript api sql uml управление база да...
# 8  разработка программный обеспечение microsoft o...

# %%
tfidf_vect_rn = TfidfVectorizer()
tfidf_matrix_rn = tfidf_vect_rn.fit_transform(df_rn['Ключевые навыки+'])
feature_names_rn = tfidf_vect_rn.get_feature_names_out()

list_output_rn = []
for i in range(len(tfidf_matrix_rn.toarray())):
    tfidf_scores_rn = tfidf_matrix_rn.toarray()[i]
    sorted_features_rn = [feature for _, feature in list(filter(lambda c: c[0] > 0.00001, sorted(zip(tfidf_scores_rn, feature_names_rn), reverse=True)))]
    list_output_rn.append(sorted_features_rn)

# %%
df_rn.insert(2, "key_words", list_output_rn)

# %%
df_rn.to_excel(r'RPD_output\dataset_res3.xlsx')

# %%
list_output_rn_1 = []
for elem in list_output_rn:
    list_output_rn_1.append(" ".join(elem))
#list_output_rn_1, len(list_output_rn_1)

# %%
list_one = list_output_rn_1 #Датасет с ключевыми словами из ООП
list_two = list_output3 #Датасет с ключевыми словами из вакансий РосНавыка

# %%
list_one.extend(list_two)

# %%
tfidf_vect_final = TfidfVectorizer()
tfidf_matrix_final = tfidf_vect_final.fit_transform(list_one)
feature_names_final = tfidf_vect_final.get_feature_names_out()
cosine_similarity_matrix_final  = cosine_similarity(tfidf_matrix_final)
create_dataframe(tfidf_matrix_final.toarray(), feature_names_final)
# Out:
#               20       abc    access   acrobat    active  activemq     adfox  \
# doc_0   0.000000  0.038710  0.037172  0.000000  0.047764  0.000000  0.051522
# doc_1   0.000000  0.036246  0.034805  0.000000  0.044723  0.000000  0.048242
# doc_2   0.000000  0.047115  0.045243  0.000000  0.000000  0.000000  0.000000
# doc_3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_4   0.000000  0.042134  0.040460  0.000000  0.000000  0.000000  0.000000
# doc_5   0.000000  0.000000  0.049349  0.075431  0.000000  0.000000  0.000000
# doc_6   0.000000  0.035055  0.033662  0.000000  0.043254  0.046656  0.000000
# doc_7   0.000000  0.046028  0.044199  0.000000  0.000000  0.061261  0.000000
# doc_8   0.000000  0.053834  0.051694  0.000000  0.000000  0.000000  0.000000
# doc_9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_18  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_20  0.310606  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_21  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_22  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_24  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_25  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_26  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_28  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_29  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_32  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_33  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_34  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_35  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_36  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_37  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_38  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_39  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_40  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_41  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_42  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_43  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_44  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_45  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_46  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_47  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_48  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_49  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_50  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_51  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_52  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_53  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_54  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# doc_55  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#            adobe       ads   adwords  ...  эстетический      этап     этика  \
# doc_0   0.038710  0.056818  0.047764  ...      0.000000  0.000000  0.000000
# doc_1   0.036246  0.000000  0.044723  ...      0.000000  0.000000  0.000000
# doc_2   0.047115  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_3   0.063778  0.000000  0.000000  ...      0.093612  0.000000  0.000000
# doc_4   0.042134  0.000000  0.051989  ...      0.000000  0.000000  0.000000
# doc_5   0.051392  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_6   0.035055  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_7   0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_8   0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_9   0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_10  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_11  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_12  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_13  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_14  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_15  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_16  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_17  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_18  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_19  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.229981
# doc_20  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_21  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_22  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_23  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_24  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_25  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_26  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_27  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_28  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_29  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_30  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_31  0.000000  0.000000  0.000000  ...      0.000000  0.246108  0.000000
# doc_32  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_33  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_34  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_35  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_36  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_37  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_38  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_39  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_40  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_41  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_42  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_43  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_44  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_45  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_46  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_47  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_48  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_49  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_50  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_51  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_52  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_53  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
# doc_54  0.000000  0.000000  0.000000  ...      0.000000  0.237059  0.000000
# doc_55  0.000000  0.000000  0.000000  ...      0.000000  0.000000  0.000000
#
#              это  эффективность      юнит  юридический   ядерный      язык  \
# doc_0   0.000000       0.034551  0.047764     0.040455  0.000000  0.032369
# doc_1   0.000000       0.032351  0.000000     0.037879  0.000000  0.030308
# doc_2   0.000000       0.042053  0.058135     0.049238  0.000000  0.039397
# doc_3   0.000000       0.000000  0.000000     0.000000  0.000000  0.053330
# doc_4   0.000000       0.037607  0.051989     0.044033  0.000000  0.035232
# doc_5   0.000000       0.000000  0.000000     0.000000  0.000000  0.042973
# doc_6   0.000000       0.031288  0.000000     0.000000  0.000000  0.029312
# doc_7   0.000000       0.041082  0.000000     0.048102  0.000000  0.038487
# doc_8   0.000000       0.048049  0.000000     0.056259  0.000000  0.045014
# doc_9   0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_10  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_11  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_12  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_13  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_14  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_15  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_16  0.000000       0.000000  0.000000     0.000000  0.000000  0.327246
# doc_17  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_18  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_19  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_20  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_21  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_22  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_23  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_24  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_25  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_26  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_27  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_28  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_29  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_30  0.000000       0.000000  0.000000     0.000000  0.000000  0.167560
# doc_31  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_32  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_33  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_34  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_35  0.000000       0.000000  0.000000     0.000000  0.000000  0.160326
# doc_36  0.000000       0.220437  0.000000     0.000000  0.000000  0.000000
# doc_37  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_38  0.280028       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_39  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_40  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_41  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_42  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_43  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_44  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_45  0.000000       0.230522  0.000000     0.000000  0.000000  0.000000
# doc_46  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_47  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_48  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_49  0.000000       0.000000  0.000000     0.000000  0.279266  0.000000
# doc_50  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_51  0.000000       0.180651  0.000000     0.000000  0.000000  0.000000
# doc_52  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_53  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_54  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
# doc_55  0.000000       0.000000  0.000000     0.000000  0.000000  0.000000
#
#           яндекс
# doc_0   0.040455
# doc_1   0.037879
# doc_2   0.049238
# doc_3   0.000000
# doc_4   0.044033
# doc_5   0.000000
# doc_6   0.036634
# doc_7   0.048102
# doc_8   0.000000
# doc_9   0.000000
# doc_10  0.000000
# doc_11  0.000000
# doc_12  0.000000
# doc_13  0.000000
# doc_14  0.000000
# doc_15  0.000000
# doc_16  0.000000
# doc_17  0.000000
# doc_18  0.000000
# doc_19  0.000000
# doc_20  0.000000
# doc_21  0.000000
# doc_22  0.000000
# doc_23  0.000000
# doc_24  0.000000
# doc_25  0.000000
# doc_26  0.000000
# doc_27  0.000000
# doc_28  0.000000
# doc_29  0.000000
# doc_30  0.000000
# doc_31  0.000000
# doc_32  0.000000
# doc_33  0.000000
# doc_34  0.000000
# doc_35  0.000000
# doc_36  0.000000
# doc_37  0.000000
# doc_38  0.000000
# doc_39  0.000000
# doc_40  0.000000
# doc_41  0.000000
# doc_42  0.000000
# doc_43  0.000000
# doc_44  0.000000
# doc_45  0.000000
# doc_46  0.000000
# doc_47  0.000000
# doc_48  0.000000
# doc_49  0.000000
# doc_50  0.000000
# doc_51  0.000000
# doc_52  0.000000
# doc_53  0.000000
# doc_54  0.000000
# doc_55  0.000000
#
# [56 rows x 1379 columns]

# %%
doc_names_list_final = [f'doc_{i}' for i, _ in enumerate(cosine_similarity_matrix_final)]

# %%
dataframe_hm_final = create_dataframe(cosine_similarity_matrix_final, doc_names_list_final)

# %%
plt.figure(figsize = (48,16))
sns.heatmap(dataframe_hm_final , cmap="Blues", annot=True, fmt=".1f") 
#, annot= True,fmt=".1f"
# Out:
# <Axes: >

# %% [markdown]
# # Обработка датасета из РосНавыка (столбец "описание вакансии")

# %%
df_rn_desc = df_rn_raw[['Специализация', 'ID вакансии', 'Название вакансии', 'Описание вакансии']]

# %%
df_rn_desc
# Out:
#                   Специализация                           ID вакансии  \
# 0      Программист, разработчик  c4a1db55-2ad0-11ee-b928-9586bb63c653
# 1      Программист, разработчик  3f692cb5-5e86-11ee-b174-d549be31d974
# 2      Программист, разработчик  20df7e05-5e01-11ee-9738-cb26dff57dd7
# 3      Программист, разработчик  be5472c5-60fa-11ee-9738-cb26dff57dd7
# 4      Программист, разработчик  7c825bf5-d50a-11ec-b20f-d768660431c4
# ...                         ...                                   ...
# 55752       Финансовый менеджер                              90043209
# 55753       Финансовый менеджер                              90043888
# 55754       Финансовый менеджер                              90054011
# 55755       Финансовый менеджер                              90073940
# 55756       Финансовый менеджер                              90095272
#
#                                        Название вакансии  \
# 0                                            Программист
# 1      Главный специалист по администрированию портал...
# 2                                         Разработчик С#
# 3      Специалист технической поддержки/ Консультант SAP
# 4                              Инженер-программист АСУТП
# ...                                                  ...
# 55752                  Менеджер по налоговой методологии
# 55753                     Финансовый менеджер (удаленно)
# 55754                                Финансовый менеджер
# 55755  Специалист/Финансовый консультант в отделение ...
# 55756                                Финансовый менеджер
#
#                                        Описание вакансии
# 0      1. Программист исполняет следующие обязанности...
# 1       Администрирование портальных решений на базе ...
# 2       Решать нетривиальные и нестандартные задачи. ...
# 3        Обработка обращений от пользователей с вопро...
# 4      -Сопровождение программного обеспечения систем...
# ...                                                  ...
# 55752  WILDBERRIES — это крупнейшая в странах ЕАЭС ме...
# 55753  DLS group —торговая транспортная компания. Наш...
# 55754  Компания Zetter ведёт активную работу по разра...
# 55755  ФИНАНСОВЫЙ КОНСУЛЬТАНТ   Хочешь всё и сразу: х...
# 55756  В Холдинговую компанию требуется Финансовый ме...
#
# [55757 rows x 4 columns]

# %%
df_rn_desc['Lemm_vac'] = df_rn_desc['Описание вакансии'].apply(Doc_func)
df_rn_desc
# Out:
# C:\Users\seismopro\AppData\Local\Temp\ipykernel_9340\220335923.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rn_desc['Lemm_vac'] = df_rn_desc['Описание вакансии'].apply(Doc_func)
#                   Специализация                           ID вакансии  \
# 0      Программист, разработчик  c4a1db55-2ad0-11ee-b928-9586bb63c653
# 1      Программист, разработчик  3f692cb5-5e86-11ee-b174-d549be31d974
# 2      Программист, разработчик  20df7e05-5e01-11ee-9738-cb26dff57dd7
# 3      Программист, разработчик  be5472c5-60fa-11ee-9738-cb26dff57dd7
# 4      Программист, разработчик  7c825bf5-d50a-11ec-b20f-d768660431c4
# ...                         ...                                   ...
# 55752       Финансовый менеджер                              90043209
# 55753       Финансовый менеджер                              90043888
# 55754       Финансовый менеджер                              90054011
# 55755       Финансовый менеджер                              90073940
# 55756       Финансовый менеджер                              90095272
#
#                                        Название вакансии  \
# 0                                            Программист
# 1      Главный специалист по администрированию портал...
# 2                                         Разработчик С#
# 3      Специалист технической поддержки/ Консультант SAP
# 4                              Инженер-программист АСУТП
# ...                                                  ...
# 55752                  Менеджер по налоговой методологии
# 55753                     Финансовый менеджер (удаленно)
# 55754                                Финансовый менеджер
# 55755  Специалист/Финансовый консультант в отделение ...
# 55756                                Финансовый менеджер
#
#                                        Описание вакансии  \
# 0      1. Программист исполняет следующие обязанности...
# 1       Администрирование портальных решений на базе ...
# 2       Решать нетривиальные и нестандартные задачи. ...
# 3        Обработка обращений от пользователей с вопро...
# 4      -Сопровождение программного обеспечения систем...
# ...                                                  ...
# 55752  WILDBERRIES — это крупнейшая в странах ЕАЭС ме...
# 55753  DLS group —торговая транспортная компания. Наш...
# 55754  Компания Zetter ведёт активную работу по разра...
# 55755  ФИНАНСОВЫЙ КОНСУЛЬТАНТ   Хочешь всё и сразу: х...
# 55756  В Холдинговую компанию требуется Финансовый ме...
#
#                                                 Lemm_vac
# 0      программист исполнять следующий обязанность ра...
# 1      администрирование портальный решение база micr...
# 2      решать нетривиальный нестандартный задача прин...
# 3      обработка обращение пользователь вопрос работа...
# 4      сопровождение программный обеспечение система ...
# ...                                                  ...
# 55752  wildberries это крупный страна еаэс международ...
# 55753  dls group транспортный компания специализация ...
# 55754  компания zetter вести активный работа разработ...
# 55755  финансовый консультант хотеть и сразу хороший ...
# 55756  холдинговый компания требоваться финансовый ме...
#
# [55757 rows x 5 columns]

# %%
df_rn_desc.to_excel(r'RPD_output/dataset_res_desc_vac_lemm.xlsx')
# Out:
# C:\Users\seismopro\AppData\Local\anaconda3\Lib\site-packages\xlsxwriter\worksheet.py:1251: UserWarning: Ignoring URL 'http://manifesto.avito.com/%20Вам%20предстоит:%20%20формировать%20и%20реализовывать%20стратегии%20развития%20отдела%20операционного%20обучения;%20управлять%20процессами%20операционного%20обучения%20для%20повышения%20качества%20и%20скорости%20обучения%20персонала%20(организация,%20планирование,%20ведение%20баз%20данных,%20обеспечение%20бесперебойного%20обучения%20согласно%20плану);%20формировать,%20поддерживать%20и%20регулярно%20оптимизировать%20процессы%20адаптации%20новых%20сотрудников;%20обеспечивать%20эффективную%20работу%20системы%20наставничества;%20внедрять%20новые%20инструменты%20в%20работу%20отдела%20для%20повышения%20качества%20обучения%20и%20адаптации;%20поддерживать%20с%20организационной%20и%20методической%20точки%20зрения%20процессы%20создания%20новых%20учебных%20курсов;%20использовать%20и%20развивать%20системы%20дистанционного%20обучения;%20развивать%20команды%20тренеров;%20анализировать%20результаты%20обучения,%20обратной%20связи,%20статистики%20по%20обучению,%20а%20также%20формировать%20и%20анализировать%20отчетность%20по%20обучению;%20разрабатывать%20мероприятия%20и%20инициативы%20для%20повышения%20эффективности%20работы%20команды;%20оказывать%20содействие%20и%20сотрудничать%20с%20руководством%20CS%20для%20формирования%20инициатив%20по%20постоянному%20улучшению%20качества%20обслуживания%20в%20Avito%20CS;%20вносить%20предложений%20руководителю%20по%20повышению%20эффективности%20работы%20отдела.%20%20Мы%20ждём,%20что%20вы:%20%20имеете%20высшее%20образование;%20работали%20на%20аналогичной%20должности%20от%203-х%20лет;%20управляли%20большими%20командами%20(от%2030%20сотрудников);%20имеете%20опыт%20совместной%20работы%20отдела%20обучения%20и%20отдела%20персонала%20(привлечение,%20адаптация%20и%20мотивация%20сотрудников);%20владеете%20современными%20технологиями%20обучения;%20знаете%20тренды%20клиентского%20сервиса%20в%20России,%20мире,%20а%20также%20знакомы%20с%20принципами%20организации%20массового%20hard%20-%20обучения%20и%20адаптации%20персонала%20в%20крупных%20компаниях;%20умеете%20повышать%20удовлетворенность%20внутренних%20и%20внешних%20клиентов.%20%20Работа%20у%20нас%20—%20это:%20%20интересные%20и%20важные%20задачи%20на%20очень%20большом%20проекте;%20передовые%20технологии%20и%20подходы,%20возможность%20пробовать%20новое;%20опытные%20и%20заинтересованные%20коллеги,%20готовые%20оказать%20поддержку;%20прозрачная%20система%20премий,%20достойная%20зарплата%20—%20размер%20обсудим%20на%20собеседовании;%20развитие%20полезных%20навыков:%20на%20курсах%20для%20сотрудников%20можно%20прокачать%20искусство%20переговоров%20или%20выучить%20английский;%20забота%20о%20здоровье:%20с%20первого%20дня%20у%20вас%20будет%20ДМС%20со%20стоматологией,%20в%20офисе%20принимают%20терапевт%20и%20массажист;%20замечательный%20офис%20в%20двух%20минутах%20от%20метро%20«Белорусская»:%20панорамный%20вид%20на%20центр%20города,%20места%20для%20уединённой%20работы%20и%20зоны%20отдыха.%20' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn(
