# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)
from razdel import tokenize
import pandas as pd

# %%
segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

# %%
text = 'Посол Израиля на Украине Йоэль Лион признался, что пришел в шок, узнав о решении властей Львовской области объявить 2019 год годом лидера запрещенной в России Организации украинских националистов (ОУН) Степана Бандеры. Свое заявление он разместил в Twitter. «Я не могу понять, как прославление тех, кто непосредственно принимал участие в ужасных антисемитских преступлениях, помогает бороться с антисемитизмом и ксенофобией. Украина не должна забывать о преступлениях, совершенных против украинских евреев, и никоим образом не отмечать их через почитание их исполнителей», — написал дипломат. 11 декабря Львовский областной совет принял решение провозгласить 2019 год в регионе годом Степана Бандеры в связи с празднованием 110-летия со дня рождения лидера ОУН (Бандера родился 1 января 1909 года). В июле аналогичное решение принял Житомирский областной совет. В начале месяца с предложением к президенту страны Петру Порошенко вернуть Бандере звание Героя Украины обратились депутаты Верховной Рады. Парламентарии уверены, что признание Бандеры национальным героем поможет в борьбе с подрывной деятельностью против Украины в информационном поле, а также остановит «распространение мифов, созданных российской пропагандой». Степан Бандера (1909-1959) был одним из лидеров Организации украинских националистов, выступающей за создание независимого государства на территориях с украиноязычным населением. В 2010 году в период президентства Виктора Ющенко Бандера был посмертно признан Героем Украины, однако впоследствии это решение было отменено судом. '
doc = Doc(text)

# %%
doc.segment(segmenter)

# %%
print(doc.tokens[:5])
print(doc.sents[:5])
# Out:
# [DocToken(stop=5, text='Посол'), DocToken(start=6, stop=13, text='Израиля'), DocToken(start=14, stop=16, text='на'), DocToken(start=17, stop=24, text='Украине'), DocToken(start=25, stop=30, text='Йоэль')]
# [DocSent(stop=218, text='Посол Израиля на Украине Йоэль Лион признался, чт..., tokens=[...]), DocSent(start=219, stop=257, text='Свое заявление он разместил в Twitter.', tokens=[...]), DocSent(start=258, stop=424, text='«Я не могу понять, как прославление тех, кто непо..., tokens=[...]), DocSent(start=425, stop=592, text='Украина не должна забывать о преступлениях, совер..., tokens=[...]), DocSent(start=593, stop=798, text='11 декабря Львовский областной совет принял решен..., tokens=[...])]

# %%
doc.tag_morph(morph_tagger)

# %%
for token in doc.tokens:
    token.lemmatize(morph_vocab)

# %%
print(doc.tokens)
# Out:
# [DocToken(stop=5, text='Посол', pos='NOUN', feats=<Anim,Nom,Masc,Sing>, lemma='посол'), DocToken(start=6, stop=13, text='Израиля', pos='PROPN', feats=<Inan,Gen,Masc,Sing>, lemma='израиль'), DocToken(start=14, stop=16, text='на', pos='ADP', lemma='на'), DocToken(start=17, stop=24, text='Украине', pos='PROPN', feats=<Inan,Loc,Fem,Sing>, lemma='украина'), DocToken(start=25, stop=30, text='Йоэль', pos='PROPN', feats=<Anim,Nom,Masc,Sing>, lemma='йоэль'), DocToken(start=31, stop=35, text='Лион', pos='PROPN', feats=<Anim,Nom,Masc,Sing>, lemma='лион'), DocToken(start=36, stop=45, text='признался', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Mid>, lemma='признаться'), DocToken(start=45, stop=46, text=',', pos='PUNCT', lemma=','), DocToken(start=47, stop=50, text='что', pos='SCONJ', lemma='что'), DocToken(start=51, stop=57, text='пришел', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Act>, lemma='прийти'), DocToken(start=58, stop=59, text='в', pos='ADP', lemma='в'), DocToken(start=60, stop=63, text='шок', pos='NOUN', feats=<Inan,Acc,Masc,Sing>, lemma='шок'), DocToken(start=63, stop=64, text=',', pos='PUNCT', lemma=','), DocToken(start=65, stop=70, text='узнав', pos='VERB', feats=<Perf,Past,Conv,Act>, lemma='узнать'), DocToken(start=71, stop=72, text='о', pos='ADP', lemma='о'), DocToken(start=73, stop=80, text='решении', pos='NOUN', feats=<Inan,Loc,Neut,Sing>, lemma='решение'), DocToken(start=81, stop=88, text='властей', pos='NOUN', feats=<Inan,Gen,Fem,Plur>, lemma='власть'), DocToken(start=89, stop=98, text='Львовской', pos='ADJ', feats=<Gen,Pos,Fem,Sing>, lemma='львовский'), DocToken(start=99, stop=106, text='области', pos='NOUN', feats=<Inan,Gen,Fem,Sing>, lemma='область'), DocToken(start=107, stop=115, text='объявить', pos='VERB', feats=<Perf,Inf,Act>, lemma='объявить'), DocToken(start=116, stop=120, text='2019', pos='ADJ', lemma='2019'), DocToken(start=121, stop=124, text='год', pos='NOUN', feats=<Inan,Acc,Masc,Sing>, lemma='год'), DocToken(start=125, stop=130, text='годом', pos='NOUN', feats=<Inan,Ins,Masc,Sing>, lemma='год'), DocToken(start=131, stop=137, text='лидера', pos='NOUN', feats=<Anim,Gen,Masc,Sing>, lemma='лидер'), DocToken(start=138, stop=149, text='запрещенной', pos='VERB', feats=<Perf,Gen,Fem,Sing,Past,Part,Pass>, lemma='запретить'), DocToken(start=150, stop=151, text='в', pos='ADP', lemma='в'), DocToken(start=152, stop=158, text='России', pos='PROPN', feats=<Inan,Loc,Fem,Sing>, lemma='россия'), DocToken(start=159, stop=170, text='Организации', pos='PROPN', feats=<Inan,Gen,Fem,Sing>, lemma='организация'), DocToken(start=171, stop=181, text='украинских', pos='ADJ', feats=<Gen,Pos,Plur>, lemma='украинский'), DocToken(start=182, stop=195, text='националистов', pos='NOUN', feats=<Anim,Gen,Masc,Plur>, lemma='националист'), DocToken(start=196, stop=197, text='(', pos='PUNCT', lemma='('), DocToken(start=197, stop=200, text='ОУН', pos='PROPN', feats=<Inan,Nom,Fem,Sing>, lemma='оун'), DocToken(start=200, stop=201, text=')', pos='PUNCT', lemma=')'), DocToken(start=202, stop=209, text='Степана', pos='PROPN', feats=<Anim,Gen,Masc,Sing>, lemma='степан'), DocToken(start=210, stop=217, text='Бандеры', pos='PROPN', feats=<Anim,Gen,Masc,Sing>, lemma='бандера'), DocToken(start=217, stop=218, text='.', pos='PUNCT', lemma='.'), DocToken(start=219, stop=223, text='Свое', pos='DET', feats=<Inan,Acc,Neut,Sing>, lemma='свой'), DocToken(start=224, stop=233, text='заявление', pos='NOUN', feats=<Inan,Acc,Neut,Sing>, lemma='заявление'), DocToken(start=234, stop=236, text='он', pos='PRON', feats=<Nom,Masc,Sing,3>, lemma='он'), DocToken(start=237, stop=246, text='разместил', pos='VERB', feats=<Perf,Masc,Ind,Sing,Past,Fin,Act>, lemma='разместить'), DocToken(start=247, stop=248, text='в', pos='ADP', lemma='в'), DocToken(start=249, stop=256, text='Twitter', pos='PROPN', feats=<Inan,Loc,Masc,Sing>, lemma='twitter'), DocToken(start=256, stop=257, text='.', pos='PUNCT', lemma='.'), DocToken(start=258, stop=259, text='«', pos='PUNCT', lemma='«'), Doc ...

# %%
{_.text: _.lemma for _ in doc.tokens}
# Out:
# {'Посол': 'посол',
#  'Израиля': 'израиль',
#  'на': 'на',
#  'Украине': 'украина',
#  'Йоэль': 'йоэль',
#  'Лион': 'лион',
#  'признался': 'признаться',
#  ',': ',',
#  'что': 'что',
#  'пришел': 'прийти',
#  'в': 'в',
#  'шок': 'шок',
#  'узнав': 'узнать',
#  'о': 'о',
#  'решении': 'решение',
#  'властей': 'власть',
#  'Львовской': 'львовский',
#  'области': 'область',
#  'объявить': 'объявить',
#  '2019': '2019',
#  'год': 'год',
#  'годом': 'год',
#  'лидера': 'лидер',
#  'запрещенной': 'запретить',
#  'России': 'россия',
#  'Организации': 'организация',
#  'украинских': 'украинский',
#  'националистов': 'националист',
#  '(': '(',
#  'ОУН': 'оун',
#  ')': ')',
#  'Степана': 'степан',
#  'Бандеры': 'бандера',
#  '.': '.',
#  'Свое': 'свой',
#  'заявление': 'заявление',
#  'он': 'он',
#  'разместил': 'разместить',
#  'Twitter': 'twitter',
#  '«': '«',
#  'Я': 'я',
#  'не': 'не',
#  'могу': 'мочь',
#  'понять': 'понять',
#  'как': 'как',
#  'прославление': 'прославление',
#  'тех': 'тот',
#  'кто': 'кто',
#  'непосредственно': 'непосредственно',
#  'принимал': 'принимать',
#  'участие': 'участие',
#  'ужасных': 'ужасный',
#  'антисемитских': 'антисемитский',
#  'преступлениях': 'преступление',
#  'помогает': 'помогать',
#  'бороться': 'бороться',
#  'с': 'с',
#  'антисемитизмом': 'антисемитизм',
#  'и': 'и',
#  'ксенофобией': 'ксенофобия',
#  'Украина': 'украина',
#  'должна': 'должный',
#  'забывать': 'забывать',
#  'совершенных': 'совершить',
#  'против': 'против',
#  'евреев': 'еврей',
#  'никоим': 'никой',
#  'образом': 'образ',
#  'отмечать': 'отмечать',
#  'их': 'они',
#  'через': 'через',
#  'почитание': 'почитание',
#  'исполнителей': 'исполнитель',
#  '»': '»',
#  '—': '—',
#  'написал': 'написать',
#  'дипломат': 'дипломат',
#  '11': '11',
#  'декабря': 'декабрь',
#  'Львовский': 'львовский',
#  'областной': 'областной',
#  'совет': 'совет',
#  'принял': 'принять',
#  'решение': 'решение',
#  'провозгласить': 'провозгласить',
#  'регионе': 'регион',
#  'связи': 'связь',
#  'празднованием': 'празднование',
#  '110-летия': '110-летие',
#  'со': 'с',
#  'дня': 'день',
#  'рождения': 'рождение',
#  'Бандера': 'бандера',
#  'родился': 'родиться',
#  '1': '1',
#  'января': 'январь',
#  '1909': '1909',
#  'года': 'год',
#  'В': 'в',
#  'июле': 'июль',
#  'аналогичное': 'аналогичный',
#  'Житомирский': 'житомирский',
#  'начале': 'начало',
#  'месяца': 'месяц',
#  'предложением': 'предложение',
#  'к': 'к',
#  'президенту': 'президент',
#  'страны': 'страна',
#  'Петру': 'петр',
#  'Порошенко': 'порошенко',
#  'вернуть': 'вернуть',
#  'Бандере': 'бандера',
#  'звание': 'звание',
#  'Героя': 'герой',
#  'Украины': 'украина',
#  'обратились': 'обратиться',
#  'депутаты': 'депутат',
#  'Верховной': 'верховный',
#  'Рады': 'рада',
#  'Парламентарии': 'парламентарий',
#  'уверены': 'уверить',
#  'признание': 'признание',
#  'национальным': 'национальный',
#  'героем': 'герой',
#  'поможет': 'помочь',
#  'борьбе': 'борьба',
#  'подрывной': 'подрывной',
#  'деятельностью': 'деятельность',
#  'информационном': 'информационный',
#  'поле': 'поле',
#  'а': 'а',
#  'также': 'также',
#  'остановит': 'остановить',
#  'распространение': 'распространение',
#  'мифов': 'миф',
#  'созданных': 'создать',
#  'российской': 'российский',
#  'пропагандой': 'пропаганда',
#  'Степан': 'степан',
#  '1909-1959': '1909-1959',
#  'был': 'быть',
#  'одним': 'один',
#  'из': 'из',
#  'лидеров': 'лидер',
#  'выступающей': 'выступать',
#  'за': 'за',
#  'создание': 'создание',
#  'независимого': 'независимый',
#  'государства': 'государство',
#  'территориях': 'территория',
#  'украиноязычным': 'украиноязычный',
#  'населением': 'население',
#  '2010': '2010',
#  'году': 'год',
#  'период': 'период',
#  'президентства': 'президентство',
#  'Виктора': 'виктор',
#  'Ющенко': 'ющенко',
#  'посмертно': 'посмертно',
#  'признан': 'признать',
#  'Героем': 'герой',
#  'однако': 'однако',
#  'впоследствии': 'впоследствии',
#  'это': 'это',
#  'было': 'быть',
#  'отменено': 'отменить',
#  'судом': 'суд'}

# %%
{_.lemma for _ in doc.tokens}
# Out:
# {'(',
#  ')',
#  ',',
#  '.',
#  '1',
#  '11',
#  '110-летие',
#  '1909',
#  '1909-1959',
#  '2010',
#  '2019',
#  'twitter',
#  '«',
#  '»',
#  'а',
#  'аналогичный',
#  'антисемитизм',
#  'антисемитский',
#  'бандера',
#  'бороться',
#  'борьба',
#  'быть',
#  'в',
#  'вернуть',
#  'верховный',
#  'виктор',
#  'власть',
#  'впоследствии',
#  'выступать',
#  'герой',
#  'год',
#  'государство',
#  'декабрь',
#  'день',
#  'депутат',
#  'деятельность',
#  'дипломат',
#  'должный',
#  'еврей',
#  'житомирский',
#  'за',
#  'забывать',
#  'запретить',
#  'заявление',
#  'звание',
#  'и',
#  'из',
#  'израиль',
#  'информационный',
#  'исполнитель',
#  'июль',
#  'йоэль',
#  'к',
#  'как',
#  'ксенофобия',
#  'кто',
#  'лидер',
#  'лион',
#  'львовский',
#  'месяц',
#  'миф',
#  'мочь',
#  'на',
#  'написать',
#  'население',
#  'националист',
#  'национальный',
#  'начало',
#  'не',
#  'независимый',
#  'непосредственно',
#  'никой',
#  'о',
#  'областной',
#  'область',
#  'образ',
#  'обратиться',
#  'объявить',
#  'один',
#  'однако',
#  'он',
#  'они',
#  'организация',
#  'остановить',
#  'отменить',
#  'отмечать',
#  'оун',
#  'парламентарий',
#  'период',
#  'петр',
#  'подрывной',
#  'поле',
#  'помогать',
#  'помочь',
#  'понять',
#  'порошенко',
#  'посмертно',
#  'посол',
#  'почитание',
#  'празднование',
#  'предложение',
#  'президент',
#  'президентство',
#  'преступление',
#  'признание',
#  'признать',
#  'признаться',
#  'прийти',
#  'принимать',
#  'принять',
#  'провозгласить',
#  'пропаганда',
#  'прославление',
#  'против',
#  'рада',
#  'разместить',
#  'распространение',
#  'регион',
#  'решение',
#  'родиться',
#  'рождение',
#  'российский',
#  'россия',
#  'с',
#  'свой',
#  'связь',
#  'совершить',
#  'совет',
#  'создание',
#  'создать',
#  'степан',
#  'страна',
#  'суд',
#  'также',
#  'территория',
#  'тот',
#  'уверить',
#  'ужасный',
#  'узнать',
#  'украина',
#  'украиноязычный',
#  'украинский',
#  'участие',
#  'через',
#  'что',
#  'шок',
#  'это',
#  'ющенко',
#  'я',
#  'январь',
#  '—'}
